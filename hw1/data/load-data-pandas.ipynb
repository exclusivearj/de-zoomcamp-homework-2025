# %%
# All imports go here
import pandas as pd
from sqlalchemy import create_engine, text,  CursorResult
import psycopg
from time import time

# %%
# endpoint = "https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2019-01.csv.gz"
endpoint = "hw1/data/yellow_tripdata_2019-01.csv.gz"

# %%
df = pd.read_csv(endpoint, compression='gzip', nrows=100)
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1          1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2          2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3          2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4          2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
# ..       ...                  ...                   ...              ...
# 95         2  2019-01-01 00:02:06   2019-01-01 00:10:19                2
# 96         2  2019-01-01 00:24:57   2019-01-01 00:35:42                2
# 97         2  2019-01-01 00:46:09   2019-01-01 01:06:46                1
# 98         1  2019-01-01 00:16:07   2019-01-01 00:19:41                1
# 99         1  2019-01-01 00:23:47   2019-01-01 00:39:41                1
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.50           1                  N           151           239
# 1            2.60           1                  N           239           246
# 2            0.00           1                  N           236           236
# 3            0.00           1                  N           193           193
# 4            0.00           2                  N           193           193
# ..            ...         ...                ...           ...           ...
# 95           2.57           1                  N            45            97
# 96           2.44           1                  N           144           256
# 97           4.18           1                  N            79           263
# 98           1.00           1                  N           140           233
# 99           3.90           1                  N           229           238
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              1          7.0    0.5      0.5        1.65           0.0
# 1              1         14.0    0.5      0.5        1.00           0.0
# 2              1          4.5    0.5      0.5        0.00           0.0
# 3              2          3.5    0.5      0.5        0.00           0.0
# 4              2         52.0    0.0      0.5        0.00           0.0
# ..           ...          ...    ...      ...         ...           ...
# 95             1          9.5    0.5      0.5        2.16           0.0
# 96             2         10.5    0.5      0.5        0.00           0.0
# 97             1         16.0    0.5      0.5        3.46           0.0
# 98             1          5.0    0.5      0.5        1.00           0.0
# 99             1         14.5    0.5      0.5        4.70           0.0
#
#     improvement_surcharge  total_amount  congestion_surcharge
# 0                     0.3          9.95                   NaN
# 1                     0.3         16.30                   NaN
# 2                     0.3          5.80                   NaN
# 3                     0.3          7.55                   NaN
# 4                     0.3         55.55                   NaN
# ..                    ...           ...                   ...
# 95                    0.3         12.96                   NaN
# 96                    0.3         11.80                   NaN
# 97                    0.3         20.76                   NaN
# 98                    0.3          7.30                   NaN
# 99                    0.3         20.50                   NaN
#
# [100 rows x 18 columns]

# %%
user="postgres"
password="postgres"
db_name = "ny_taxi"
hostname="localhost"
DATABASE_URL = f"postgresql+psycopg://{user}:{password}@{hostname}:5433/{db_name}"

# Create an engine instance
engine = create_engine(DATABASE_URL)

# %%
'''
# Example usage: connect and execute a query
with engine.connect() as connection:
    result:list = connection.execute(text("SELECT datname FROM pg_database;")).all()
    total_rows = len(result)
    print("Total rows: [{total_rows}]")
    for index, row in enumerate(result, start=1):
        print(f"({index} of {total_rows}), [{row}]")
'''
# Out:
# '\n# Example usage: connect and execute a query\nwith engine.connect() as connection:\n    result:list = connection.execute(text("SELECT datname FROM pg_database;")).all()\n    total_rows = len(result)\n    print("Total rows: [{total_rows}]")\n    for index, row in enumerate(result, start=1):\n        print(f"({index} of {total_rows}), [{row}]")\n'

# %%
# Create the table
# Get the schema
schema = print(pd.io.sql.get_schema(df, name = "yellow_taxi_data", con = engine))
print(schema)
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )
#
#
# None

# %%
# Write the results to db
df_iter = pd.read_csv(endpoint, iterator=True, chunksize=100000)
# df_iter = pd.read_csv("hw1/data/small.csv", iterator=True, chunksize=100000)

start_time = time()
while (df := next(df_iter, None)) is not None:
    t_start = time()
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
    t_end = time()
    print('inserted another chunk, took %.3f second' % (t_end - t_start))

end_time = time()
print(f"Final insertion took {end_time - start_time} seconds")
# Out:
# inserted another chunk, took 2.424 second
# inserted another chunk, took 2.275 second
# inserted another chunk, took 2.246 second
# inserted another chunk, took 2.277 second
# inserted another chunk, took 2.440 second
# inserted another chunk, took 2.320 second
# inserted another chunk, took 2.443 second
# inserted another chunk, took 2.259 second
# inserted another chunk, took 2.258 second
# inserted another chunk, took 2.272 second
# inserted another chunk, took 2.269 second
# inserted another chunk, took 2.237 second
# inserted another chunk, took 2.300 second
# inserted another chunk, took 2.298 second
# inserted another chunk, took 2.354 second
# inserted another chunk, took 2.588 second
# inserted another chunk, took 2.401 second
# inserted another chunk, took 2.230 second
# inserted another chunk, took 2.315 second
# inserted another chunk, took 2.236 second
# inserted another chunk, took 2.319 second
# inserted another chunk, took 2.313 second
# inserted another chunk, took 2.391 second
# inserted another chunk, took 2.347 second
# inserted another chunk, took 2.333 second
# inserted another chunk, took 2.389 second
# inserted another chunk, took 2.355 second
# inserted another chunk, took 2.217 second
# inserted another chunk, took 2.390 second
# inserted another chunk, took 2.227 second
# inserted another chunk, took 2.205 second
# inserted another chunk, took 2.285 second
# inserted another chunk, took 2.286 second
# inserted another chunk, took 2.408 second
# inserted another chunk, took 2.546 second
# inserted another chunk, took 2.378 second
# inserted another chunk, took 2.550 second
# inserted another chunk, took 2.336 second
# inserted another chunk, took 2.580 second
# inserted another chunk, took 2.520 second
# inserted another chunk, took 2.482 second
# inserted another chunk, took 2.282 second
# inserted another chunk, took 2.462 second
# inserted another chunk, took 2.520 second
# inserted another chunk, took 2.250 second
# inserted another chunk, took 2.398 second
# inserted another chunk, took 2.267 second
# inserted another chunk, took 2.350 second
# inserted another chunk, took 2.371 second
# inserted another chunk, took 2.249 second
# inserted another chunk, took 2.235 second
# inserted another chunk, took 2.369 second
# inserted another chunk, took 2.242 second
# inserted another chunk, took 2.216 second
# inserted another chunk, took 2.344 second
# inserted another chunk, took 2.243 second
# inserted another chunk, took 2.257 second
# inserted another chunk, took 2.275 second
# inserted another chunk, took 2.310 second
# inserted another chunk, took 2.244 second
# inserted another chunk, took 2.260 second
# inserted another chunk, took 2.273 second
# inserted another chunk, took 2.239 second
# inserted another chunk, took 2.227 second
# inserted another chunk, took 2.228 second
# inserted another chunk, took 2.296 second
# inserted another chunk, took 2.884 second
# inserted another chunk, took 3.571 second
# inserted another chunk, took 3.673 second
# inserted another chunk, took 3.517 second
# inserted another chunk, took 3.467 second
# inserted another chunk, took 3.617 second
# inserted another chunk, took 4.850 second
# inserted another chunk, took 3.558 second
# inserted another chunk, took 2.413 second
# inserted another chunk, took 1037.111 second
# inserted another chunk, took 1.595 second
# Final insertion took 1231.624234199524 seconds

# %%
'''
# Get all the data
with engine.connect() as connection:
    result:list = connection.execute(text("SELECT * FROM yellow_taxi_data;")).all()
    total_rows = len(result)
    print(f"Total rows: [{total_rows}]")
    for index, row in enumerate(result, start=1):
        print(f"({index} of {total_rows}), [{row}]")
'''
# Out:
# '\n# Get all the data\nwith engine.connect() as connection:\n    result:list = connection.execute(text("SELECT * FROM yellow_taxi_data;")).all()\n    total_rows = len(result)\n    print(f"Total rows: [{total_rows}]")\n    for index, row in enumerate(result, start=1):\n        print(f"({index} of {total_rows}), [{row}]")\n'

# %%
# Get row count
with engine.connect() as connection:
    result:list = connection.execute(text("SELECT count(1) FROM yellow_taxi_data;")).all()
    total_rows = len(result)
    print(f"Total rows: [{total_rows}]")
    for index, row in enumerate(result, start=1):
        print(f"({index} of {total_rows}), [{row}]")
# Out:
# Total rows: [1]
# (1 of 1), [(7667792,)]
